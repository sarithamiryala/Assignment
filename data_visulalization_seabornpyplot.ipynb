# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4664/1654069430.py in <module>
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
# ----> 4 import seaborn as sns
#       5 get_ipython().run_line_magic('matplotlib', 'inline')
#
# ~\AppData\Roaming\Python\Python39\site-packages\seaborn\__init__.py in <module>
#       1 # Import seaborn objects
# ----> 2 from .rcmod import *  # noqa: F401,F403
#       3 from .utils import *  # noqa: F401,F403
#       4 from .palettes import *  # noqa: F401,F403
#       5 from .relational import *  # noqa: F401,F403
#
# ~\AppData\Roaming\Python\Python39\site-packages\seaborn\rcmod.py in <module>
#       5 import matplotlib as mpl
#       6 from cycler import cycler
# ----> 7 from . import palettes
#       8
#       9
#
# ~\AppData\Roaming\Python\Python39\site-packages\seaborn\palettes.py in <module>
#       7 from .external import husl
#       8
# ----> 9 from .utils import desaturate, get_color_cycle
#      10 from .colors import xkcd_rgb, crayons
#      11
#
# ~\AppData\Roaming\Python\Python39\site-packages\seaborn\utils.py in <module>
#       8
#       9 import numpy as np
# ---> 10 from scipy import stats
#      11 import pandas as pd
#      12 import matplotlib as mpl
#
# ~\AppData\Roaming\Python\Python39\site-packages\scipy\stats\__init__.py in <module>
#     439 """
#     440
# --> 441 from .stats import *
#     442 from .distributions import *
#     443 from .morestats import *
#
# ~\AppData\Roaming\Python\Python39\site-packages\scipy\stats\stats.py in <module>
#      41 import scipy.special as special
#      42 from scipy import linalg
# ---> 43 from . import distributions
#      44 from . import mstats_basic
#      45 from ._stats_mstats_common import (_find_repeats, linregress, theilslopes,
#
# ~\AppData\Roaming\Python\Python39\site-packages\scipy\stats\distributions.py in <module>
#       6 #       instead of `git blame -Lxxx,+x`.
#       7 #
# ----> 8 from ._distn_infrastructure import (rv_discrete, rv_continuous, rv_frozen)
#       9
#      10 from . import _continuous_distns
#
# ~\AppData\Roaming\Python\Python39\site-packages\scipy\stats\_distn_infrastructure.py in <module>
#      22 # for root finding for continuous distribution ppf, and max likelihood
#      23 # estimation
# ---> 24 from scipy import optimize
#      25
#      26 # for functions of continuous distributions (e.g. moments, entropy, cdf)
#
# ~\AppData\Roaming\Python\Python39\site-packages\scipy\optimize\__init__.py in <module>
#     398 """
#     399
# --> 400 from .optimize import *
#     401 from ._minimize import *
#     402 from ._root import *
#
# ~\AppData\Roaming\Python\Python39\site-packages\scipy\optimize\optimize.py in <module>
#      34                          line_search_wolfe2 as line_search,
#      35                          LineSearchWarning)
# ---> 36 from ._numdiff import approx_derivative
#      37 from scipy._lib._util import getfullargspec_no_self as _getfullargspec
#      38 from scipy._lib._util import MapWrapper
#
# ~\AppData\Roaming\Python\Python39\site-packages\scipy\optimize\_numdiff.py in <module>
#       4 from numpy.linalg import norm
#       5
# ----> 6 from scipy.sparse.linalg import LinearOperator
#       7 from ..sparse import issparse, csc_matrix, csr_matrix, coo_matrix, find
#       8 from ._group_columns import group_dense, group_sparse
#
# ~\AppData\Roaming\Python\Python39\site-packages\scipy\sparse\linalg\__init__.py in <module>
#     109 """
#     110
# --> 111 from .isolve import *
#     112 from .dsolve import *
#     113 from .interface import *
#
# ~\AppData\Roaming\Python\Python39\site-packages\scipy\sparse\linalg\isolve\__init__.py in <module>
#       2
#       3 #from info import __doc__
# ----> 4 from .iterative import *
#       5 from .minres import minres
#       6 from .lgmres import lgmres
#
# ~\AppData\Roaming\Python\Python39\site-packages\scipy\sparse\linalg\isolve\iterative.py in <module>
#     148                )
#     149 @non_reentrant()
# --> 150 def bicg(A, b, x0=None, tol=1e-5, maxiter=None, M=None, callback=None, atol=None):
#     151     A,M,x,b,postprocess = make_system(A, M, x0, b)
#     152
#
# ~\AppData\Roaming\Python\Python39\site-packages\scipy\_lib\_threadsafety.py in decorator(func)
#      55             msg = "%s is not re-entrant" % func.__name__
#      56         lock = ReentrancyLock(msg)
# ---> 57         return lock.decorate(func)
#      58     return decorator
#
# ~\AppData\Roaming\Python\Python39\site-packages\scipy\_lib\_threadsafety.py in decorate(self, func)
#      43             with self:
#      44                 return func(*a, **kw)
# ---> 45         return scipy._lib.decorator.decorate(func, caller)
#      46
#      47
#
# AttributeError: module 'scipy' has no attribute '_lib'

# %%
import numpy as np
import matplotlib.pyplot as plt
from plotly.offline import iplot
import plotly as py
import plotly.tools as tls
import cufflinks as cf
# %matplotlib inline
py.offline.init_notebook_mode(connected=True)
cf.go_offline()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4664/1714524308.py in <module>
# ----> 1 py.offline.init_notebook_mode(connected=True)
#       2 cf.go_offline()
#
# NameError: name 'py' is not defined
